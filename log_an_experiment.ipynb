# %% [markdown]
# # Install MLFlow & the DagsHub python client

# %%
# %pip install -q dagshub mlflow
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Use the DagsHub client to setup connection information for MLflow

# %%
import dagshub
dagshub.init(repo_owner='aliciiaalb', repo_name='mental-health-checkin', mlflow=True)
# Out:
# Accessing as aliciiaalb
# Initialized MLflow to track repo "aliciiaalb/mental-health-checkin"
# Repository aliciiaalb/mental-health-checkin initialized!

# %% [markdown]
# # Use MLflow to log params and metrics

# %%
import mlflow
with mlflow.start_run():
  # Your training code here...
  mlflow.log_metric('accuracy', 42)
  mlflow.log_param('Param name', 'Value')
# Out:
# 🏃 View run bustling-goose-797 at: https://dagshub.com/aliciiaalb/mental-health-checkin.mlflow/#/experiments/0/runs/a4e131400c994c479c2b3708cf772d85
# 🧪 View experiment at: https://dagshub.com/aliciiaalb/mental-health-checkin.mlflow/#/experiments/0

# %% [markdown]
# Or turn on autologging for most popular ML frameworks,
# then run your training code without any modification!
#
# For more info and list of supported frameworks, see:
# [https://mlflow.org/docs/latest/tracking.html#automatic-logging](https://mlflow.org/docs/latest/tracking.html#automatic-logging)

# %%
mlflow.autolog()
